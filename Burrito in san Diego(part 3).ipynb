# %% [markdown]
# # Futher analysis of Burrito in San Diego

# %% [markdown]
# Each day there will be a new question arise for analysis

# %% [markdown]
# We can find many question to be analysized in all the website in which the data is uploaded so even i have few more question to be analysized and will be doing in this part 3

# %% [markdown]
# Our analysis of the burrito dataset including

# %% [raw]
# Descriptive statistics

# %% [raw]
# Taco shop ranking

# %% [raw]
# Modeling of overall satisfaction as a function of individual burrito dimensions

# %% [raw]
# Principal component analysis

# %% [markdown]
# # importing all the modules used for analysing the data

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # reading the data

# %%
burritos=pd.read_csv('burritos_01022018.csv')

# %% [markdown]
# # Desciptive Statistics

# %%
burritos.head()#getting data of top 5
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3   NaN
# 2                                                NaN   NaN     NaN   NaN
# 3                                                NaN   NaN     NaN   NaN
# ...

# %%
#we need to replace all the null value with mean of the column
burritos = burritos.fillna(burritos.mean())

# %% [markdown]
# # Lets analysis from starting so by seeing the data lets see the total of unique burritos that is prepared, and total of toco shops , total number of rewiers, cost

# %%
print('Total number of all burritos:',burritos.shape[0])
print('Number of burritos prepared with unique burrito',burritos.Burrito.nunique())
print('Number of restaurants:',burritos.Location.nunique())
print('Number of reviewers:', burritos.Reviewer.nunique())
print('Total cost: ${:.2f}'.format(burritos.Cost.sum()))
# Out:
# Total number of all burritos: 385
# Number of burritos prepared with unique burrito 123
# Number of restaurants: 103
# Number of reviewers: 91
# Total cost: $2713.59

# %%
plt.figure(figsize=(15,25))
sns.countplot(data=burritos,y='Location')

# %%
plt.figure(figsize=(15,25))
sns.countplot(data=burritos,y='Burrito')

# %%
plt.figure(figsize=(15,25))
sns.countplot(data=burritos,y='Reviewer')

# %% [markdown]
# # Now lets see how each dimensions effect the restaurants

# %%
x = burritos.groupby('Location').size().reset_index()
temp = x.sort_values(ascending=False, by=0)
temp = temp[:15]
y = pd.DataFrame()
for name in temp['Location']:
    y = y.append(burritos[(burritos['Location']==name)])

# %% [markdown]
# Here to see a beautiful plot of variance of the places based on each dimension we shall take the data which we have found in our part2 and taking by that places we shall compair oly with those places

# %% [markdown]
# Here if we code for a single location we get single graph and as we need to compare we shall code all the locations all together

# %% [markdown]
# # Example for single graph

# %%
x = y[(y['Location']=='Valentines Mexican Food')]
ax = sns.distplot(x['Tortilla'], color='purple', hist=False, label='Valentine Mexican Food')
# Out:
# C:\Users\User\Desktop\python\New folder\anaconda1\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Here we are considering only top best and last best taco shows based on the overall rating and seeing the variation of each dimension between the taco shops

# %% [markdown]
# # For Volume

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Volume'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Volume'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Volume'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Volume'], color='yellow', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Volume Rating')
ax
# Out:
# Text(0.5, 0, 'Volume Rating')

# %% [markdown]
# # For Tortilla

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Tortilla'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Tortilla'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Tortilla'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Tortilla'], color='yellow', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Tortilla Rating')
ax
# Out:
# Text(0.5, 0, 'Tortilla Rating')

# %% [markdown]
# # For temparature

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Temp'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Temp'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Temp'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Temp'], color='yellow', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Temp Rating')
ax
# Out:
# Text(0.5, 0, 'Temp Rating')

# %% [markdown]
# # For Meat Flavour

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Meat'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Meat'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Meat'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Meat'], color='yellow', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Meat Rating')
ax
# Out:
# Text(0.5, 0, 'Meat Rating')

# %% [markdown]
# # For Non Meat Flavour

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Fillings'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Fillings'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Fillings'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Fillings'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Fillings Rating')
ax
# Out:
# Text(0.5, 0, 'Fillings Rating')

# %% [markdown]
# # For Meat Filling ratio

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Meat:filling'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Meat:filling'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Meat:filling'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Meat:filling'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Meat:fillings Rating')
ax
# Out:
# Text(0.5, 0, 'Meat:fillings Rating')

# %% [markdown]
# # For Uniformity

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Uniformity'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Uniformity'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Uniformity'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Uniformity'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Uniformity Rating')
ax
# Out:
# Text(0.5, 0, 'Uniformity Rating')

# %% [markdown]
# # For Salsa

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Salsa'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Salsa'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Salsa'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Salsa'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Salsa Rating')
ax
# Out:
# Text(0.5, 0, 'Salsa Rating')

# %% [markdown]
# # For Synergy

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Synergy'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Synergy'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Synergy'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Synergy'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Synergy Rating')
ax
# Out:
# Text(0.5, 0, 'Synergy Rating')

# %% [markdown]
# # For Wrap

# %%
plt.rcParams['figure.figsize'] = (20.0, 5.0)

x = y[(y['Location']=='California Burritos')]
ax = sns.distplot(x['Wrap'], color='red', hist=False, label='California Burritos')
x = y[(y['Location']=='Taco Stand')]
ax = sns.distplot(x['Wrap'], color='blue', hist=False, label='Taco Stand')
x = y[(y['Location']=="Lucha Libre North Park")]
ax = sns.distplot(x['Wrap'], color='green', hist=False, label='Lucha Libre North Park')
x = y[(y['Location']=="Los Primos Mexican Food")]
ax = sns.distplot(x['Wrap'], color='black', hist=False, label='Los Primos Mexican Food')
ax.set_ylabel('Density')
ax = ax.set_xlabel('Wrap Rating')
ax
# Out:
# Text(0.5, 0, 'Wrap Rating')

# %% [markdown]
# # lets see how the overall rating (which includes all the 10 dimentions used to prepare burrito) include in variation of restaurants

# %%
x = burritos.groupby('Location').size().reset_index()
temp = x.sort_values(ascending=False, by=0)
temp
temp = temp[:15]
y = pd.DataFrame()
for name in temp['Location']:
    y = y.append(burritos[(burritos.Location==name)])
x = y.groupby('Location').mean().reset_index()
x = x.sort_values(by = ['overall','Location'],ascending=[False,False],)
x[[ 'overall','Location']]

plt.figure(figsize=(15,10))
graph = sns.barplot( x = x['overall'],y = x['Location'])
graph.set_xlabel('Rating')
graph.set_ylabel('Location')
graph = graph.set_title('Overall Ranking for Locations with 5 or more reviews')

# %% [markdown]
# # Now lets see the best burritos based on overall ratings

# %% [markdown]
# first lets sort i.e arrange the burritos according to the overall rating from decreasing order(from best burrito rated)

# %%
x = burritos.groupby('Burrito').size().reset_index()#in this 1st we shall see the total number of each burritos

temp = x.sort_values(ascending=False, by=0)#here we shall sort it according to the highest total no. of burritos prepared
temp
temp = temp[:15]#nowing taking best of 15
y = pd.DataFrame()#initialising a new table were we can add the columns nd rows accordingly after sorting
for name in temp['Burrito']:
    y = y.append(burritos[(burritos.Burrito==name)])
#now the new y dataframe is appended with new datasheet with first 15 best burritos
x = y.groupby('Burrito').mean().reset_index()#now taking mean of each burrito
x = x.sort_values(by = ['overall','Burrito'],ascending=[False,False],)
x[[ 'overall','Burrito']]#displaying it
# Out:
#      overall                    Burrito
# 7   4.175000     Carne asada everything
# 11  4.146154                      Local
# 5   4.043201      California Everything
# 4   3.916667  California - Pork Adobada
# 3   3.832692                California
# 1   3.766667                  Al pastor
# 2   3.719048                 California
# 14  3.581250          Surfin California
# 6   3.490741                Carne asada
# 8   3.450000                   Carnitas
# 0   3.328571                    Adobada
# 13  3.293654                Surf & Turf
# 10  3.000000                  Holy Moly
# 9   2.560000                     Custom
# 12  2.500000                     Pastor

# %% [markdown]
# here lets take total no. of each burrito which is prepared

# %%
 x = burritos.groupby('Burrito').size().reset_index()

temp = x.sort_values(ascending=False, by=0)
temp = temp[:15]
temp
# Out:
#                        Burrito   0
# 27                  California  91
# 46                 Carne asada  27
# 28                 California   26
# 49                    Carnitas  17
# 106                Surf & Turf  15
# 36       California Everything  14
# 79                       Local  13
# 7                    Al pastor   9
# 110          Surfin California   8
# 3                      Adobada   7
# 76                   Holy Moly   5
# 63                      Custom   5
# 47      Carne asada everything   4
# 87                      Pastor   3
# 32   California - Pork Adobada   3

# %% [markdown]
# now plotting the best 15 burritos in a pie graph for better understanding

# %%
Burrito_=['Carne asada everything','Local','California Everything','California - Pork Adobada','California','Al pastor','California','Surfin California','Carne asada','Carnitas','Adobada','Surf & Turf','Holy Moly','Custom','Pastor']
values=[27,13,14,3,91,9,26,8,27,17,7,8,5,5,3]
plt.pie(values,labels=Burrito_,radius=4)
# Out:
# ([<matplotlib.patches.Wedge at 0x293e90d1b70>,
# ...
#  [Text(4.173133395878334, 1.3946173884635782, 'Carne asada everything'),
#   Text(3.064468773990772, 3.1573772554504, 'Local'),
#   Text(1.9057053533532458, 3.965890455648111, 'California Everything'),
#   Text(1.0667227702670716, 4.268735472173668, 'California - Pork Adobada'),
#   Text(-3.385563290783762, 2.810331155593132, 'California'),
#   Text(-3.857773135289754, -2.1160308212870302, 'Al pastor'),
#   Text(-2.6663719528274146, -3.5000658006922274, 'California'),
#   Text(-1.0667224455369322, -4.268735553321113, 'Surfin California'),
#   Text(0.7583004290285991, -4.33416433229464, 'Carne asada'),
#   Text(2.830501890694104, -3.3687177155079504, 'Carnitas'),
#   Text(3.6675660305205295, -2.4308351264065378, 'Adobada'),
#   Text(4.042076081635333, -1.7382810331679834, 'Surf & Turf'),
#   Text(4.2622883382423735, -1.092198755576598, 'Holy Moly'),
#   Text(4.362071043236795, -0.5764860915538746, 'Custom'),
# ...

# %%
plt.figure(figsize=(30,6))
sns.barplot(x=Burrito_,y=values)

# %% [markdown]
# #  Predicting overall satisfaction from burrito dimensions

# %% [markdown]
# knowing how each dimension will help in overall rating

# %%
# Define predictors of the model
features = ['Hunger','Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Wrap','Cost']
import statsmodels.api as sm
# here in the below if burritos[] is not used instead if oly np.hstack is used then only overall is added to features as we are using the stored data name the overall rating with all the columns will be included
burritos_new = burritos[np.hstack((features,'overall'))].dropna()
# Run model and display results
X = sm.add_constant(burritos_new[features])
y = burritos_new['overall']

burrito_glm = sm.GLM(y,X)
res = burrito_glm.fit()
newidx = np.argsort(-res.params.values)
temp = np.arange(len(newidx))
newidx = np.delete(newidx,temp[newidx==0])

plt.figure(figsize=(12,4))
plt.bar(np.arange(len(newidx)), res.params[newidx].values, color='.5',yerr=res.bse[newidx].values)
plt.xticks(np.arange(len(newidx)),res.bse[newidx].keys(), size=12)
plt.yticks(np.arange(0,.6,.1), size=12)
plt.ylim((0,.5))
plt.xlabel('Burrito feature', size=20)
plt.ylabel('Model coefficient', size=20)
# Out:
# Text(0, 0.5, 'Model coefficient')

# %% [markdown]
# # Principal component analysis

# %% [markdown]
# Principal component analysis (PCA) is a technique used for identification of a smaller number of uncorrelated variables known as principal components from a larger set of data. Analysis involves techniques to help produce a smaller number of linear combinations on variables so that the reduced variables account for and explain most the variance in correlation matrix pattern.

# %%
from sklearn.decomposition import PCA
# Determine features to use in computing prinicple components
features = burritos[['Volume','Tortilla','Temp','Meat','Fillings','Meat:filling',
            'Uniformity','Salsa','Synergy','Wrap']]

# Replace NaN with mean value (mainly applies to ratings missing Volume measurement)
features = features.fillna(features.mean())

# Normalize each dimension
features = (features - features.mean()) / features.std()

# Apply PCA
pca = PCA(n_components=2)
pca.fit(features)

# Display principal components
pcinfo = {}
pcinfo['Burrito dimension'] = features.keys()
pcinfo['Component 1 weight'] = pca.components_[0]
pcinfo['Component 2 weight'] = pca.components_[1]
print(pd.DataFrame.from_dict(pcinfo))
print('\nExplained variance from first 2 PCs:', pca.explained_variance_ratio_)
# Out:
#   Burrito dimension  Component 1 weight  Component 2 weight
# 0            Volume           -0.038649            0.597863
# 1          Tortilla           -0.303991            0.024872
# 2              Temp           -0.209587           -0.191225
# 3              Meat           -0.393057            0.192518
# 4          Fillings           -0.410718            0.266220
# 5      Meat:filling           -0.351425           -0.260700
# 6        Uniformity           -0.300440           -0.326763
# 7             Salsa           -0.319194            0.067572
# 8           Synergy           -0.446331            0.170559
# 9              Wrap           -0.155325           -0.537627
#
# Explained variance from first 2 PCs: [0.35368952 0.12547146]

# %% [markdown]
# # Difference between across-restaurant variance and within-restaurant variance

# %% [markdown]
# here let us see how the consistancy of the burrito dimension is constant within the shops, across the shop how is the consistency of the burito quality and within with around the shops

# %%
feats = ['Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Synergy','Wrap','overall', 'Hunger']

# Compute variance within restaurants
var_within_rest = burritos.groupby('Location')[feats].var().mean()
var_across_rest = burritos.groupby('Location')[feats].mean().var()
var_within_by_across = var_within_rest / var_across_rest

df_var = pd.DataFrame({'within shop': var_within_rest,
                       'across shop': var_across_rest, 
                       'within : across': var_within_by_across})
df_var = df_var.stack().reset_index().rename(columns={'level_0':'Feature', 'level_1': 'type', 0: 'Variance'})

plt.figure(figsize=(10,5))
sns.barplot(x='type', y='Variance', hue='Feature', data=df_var, palette='winter',
            hue_order=var_within_by_across.sort_values().index,
            order = ['within shop', 'across shop', 'within : across'])
plt.gca().legend(title='Location', fontsize=15, loc='center left', bbox_to_anchor=(1, 0.5))
plt.setp(plt.gca().get_legend().get_title(), fontsize='15')
plt.xlabel('Variance type', size=15)
plt.ylabel('Normalized Variance', size=15)
plt.xticks(size=15)
plt.yticks(np.arange(0, 2.5, .5), size=15)
plt.ylim((0,2))

feats = ['Volume', 'Cost']
